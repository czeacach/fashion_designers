# %% [markdown]
# <a href="https://colab.research.google.com/github/czeacach/fashion_designers/blob/main/wdt_r%C3%A9seaux_relations_professionnelles_fashiondesigners.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Relations réciproques entres personnes et avec les institutions
#
# ### ajouter parent organization? LVMH Kering
# ### ajouter les fashion journalist et fashion editor

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from IPython.core.display import display, HTML
import os

# %%
# !pip install itables
# !pip install netgraph
# Out:
# Requirement already satisfied: itables in /usr/local/lib/python3.10/dist-packages (2.1.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from itables) (7.34.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from itables) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from itables) (2.0.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->itables) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->itables) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->itables) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->itables) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->itables) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->itables) (3.0.45)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->itables) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->itables) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->itables) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->itables) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->itables) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->itables) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->itables) (2024.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->itables) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->itables) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->itables) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->itables) (1.16.0)
# Requirement already satisfied: netgraph in /usr/local/lib/python3.10/dist-packages (4.13.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from netgraph) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from netgraph) (1.11.4)
# Requirement already satisfied: matplotlib>=1.5 in /usr/local/lib/python3.10/dist-packages (from netgraph) (3.7.1)
# Requirement already satisfied: rectangle-packer in /usr/local/lib/python3.10/dist-packages (from netgraph) (2.0.2)
# Requirement already satisfied: grandalf in /usr/local/lib/python3.10/dist-packages (from netgraph) (0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->netgraph) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->netgraph) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->netgraph) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->netgraph) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->netgraph) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->netgraph) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->netgraph) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->netgraph) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=1.5->netgraph) (1.16.0)

# %%
from itables import init_notebook_mode, show
from netgraph import Graph, InteractiveGraph

# %%
# !pip install pyvis
# Out:
# Requirement already satisfied: pyvis in /usr/local/lib/python3.10/dist-packages (0.3.2)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from pyvis) (7.34.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.1.4)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.0.4)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (3.0.45)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9.6->pyvis) (2.1.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.13)

# %%
from pyvis.network import Network

# %% [markdown]
# ## Production des données
#
# Requête exécutée sur le serveur https://query.wikidata.org/
# Propriétés prises en compte après inspection des propriétés de la population : educated at (2134) / member of (191)/ employer (421)
#
#
#
# ```
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX wd: <http://www.wikidata.org/entity/>
# PREFIX wdt: <http://www.wikidata.org/prop/direct/>
#
# SELECT DISTINCT ?item ?itemLabel (?year AS ?birthYear) ?r_property ?organisation ?organisationLabel ?coordinates
# WHERE {
#   {
#     { ?item wdt:P106 wd:Q3501317 } # occupation is fashion designer.
#     UNION
#     { ?item wdt:P101 wd:Q29583 } # field of work is fashion design
#     ?item wdt:P31 wd:Q5; # Any instance of a human.
#           wdt:P569 ?birthDate.
#     BIND(REPLACE(str(?birthDate), "(.*)([0-9]{4})(.*)", "$2") AS ?year)
#     FILTER(xsd:integer(?year) > 1800 && xsd:integer(?year) < 2001)
#
#     {
#       { ?item wdt:P463 ?organisation.
#         BIND('member_of' AS ?r_property) }
#       UNION
#       { ?item wdt:P69 ?organisation.
#         BIND('educated_at' AS ?r_property) }
#       UNION
#       { ?item wdt:P108 ?organisation.
#         BIND('employer' AS ?r_property) }
#     }
#
#     OPTIONAL { ?organisation wdt:P625 ?coordinates }
#     SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }
#   }
# }
# ORDER BY ?year
#
# ```

# %%
### Ouvrir le fichier et créer un DataFrame
fd = '/content/drive/MyDrive/dossier de travail/wdt_analyse_reseaux.csv'
df = pd.read_csv(fd)
len(df)
# Out:
# 2667

# %%
### Ajouter deux périodes différentes en fonctions de la relation
# Pour la relation 'étudier' créer une période entre 18 et 28 ans (+17, +27) pour l'étendue des études
# Pour la relation 'employer' ajouté une période d'activité de 19 à 65 ans
df['YBegin'] = df[['birthYear', 'r_property']].apply(lambda x : int(x['birthYear'] + 17) if x['r_property'] == 'educated_at' else int(x['birthYear'] + 27), axis=1)
df['YEnd'] = df[['birthYear', 'r_property']].apply(lambda x : int(x['birthYear'] + 28) if x['r_property'] == 'employer' else int(x['birthYear'] + 64), axis=1)

# %%
### Inspecter DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2667 entries, 0 to 2666
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   item               2667 non-null   object
#  1   itemLabel          2667 non-null   object
#  2   birthYear          2667 non-null   int64
#  3   r_property         2667 non-null   object
#  4   organisation       2667 non-null   object
#  5   organisationLabel  2667 non-null   object
#  6   coordinates        2073 non-null   object
#  7   YBegin             2667 non-null   int64
#  8   YEnd               2667 non-null   int64
# dtypes: int64(3), object(6)
# memory usage: 187.6+ KB

# %%
### Inspecter la distribution des années de naissance
df.birthYear.describe()
# Out:
# count                2667.0
# mean      1958.931008623922
# std      28.303820699007954
# min                  1805.0
# 25%                  1945.0
# 50%                  1966.0
# 75%                  1980.0
# max                  2000.0
# Name: birthYear, dtype: float64

# %%
df.tail()
# Out:
#                                            item          itemLabel  birthYear  \
# 2662  http://www.wikidata.org/entity/Q118082384      Javi Guijarro       2000
# 2663  http://www.wikidata.org/entity/Q118082384      Javi Guijarro       2000
# 2664  http://www.wikidata.org/entity/Q118082384      Javi Guijarro       2000
# 2665  http://www.wikidata.org/entity/Q114051014  Giulia Frangiluna       2000
# 2666  http://www.wikidata.org/entity/Q118082384      Javi Guijarro       2000
#
#        r_property                              organisation  \
# 2662     employer  http://www.wikidata.org/entity/Q22001324
# 2663     employer  http://www.wikidata.org/entity/Q25432114
# 2664     employer  http://www.wikidata.org/entity/Q61586861
# 2665  educated_at      http://www.wikidata.org/entity/Q5518
# 2666  educated_at   http://www.wikidata.org/entity/Q5397540
#
#                      organisationLabel            coordinates  YBegin  YEnd
# 2662                           Karol G                    NaN    2027  2028
# 2663                          Bad Gyal                    NaN    2027  2028
# 2664                    Rauw Alejandro                    NaN    2027  2028
# 2665                    liceo classico                    NaN    2017  2064
# 2666  Esdi, Escola Superior de Disseny  Point(2.1165 41.5436)    2017  2064

# %%
## intégrer la table dans la base de données --> ( table wdt_relations)
### nettoyer les données

# Beaucoup d'écoles/universités ont fusionné et changé de nom au cours du temps--> harmoniser avec un seul nom ?
#New York University < = New York University Institute of Fines Arts

# %%
### Compter par propriété
df.groupby(by='r_property').size()
# Out:
# r_property
# educated_at    2101
# employer        377
# member_of       189
# dtype: int64

# %%
organisations = df.groupby(by='organisationLabel').size()
show(organisations.sort_index(ascending=False))
# Out:
# <table id="itables_ab8740b0_7251_4d0e_9f0b_08dfcabc3aa5" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#     <tr>
#       <th>organisationLabel</th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.0 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.7/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.7/dt_bundle.js';
#
#     document.querySelectorAll("#itables_ab8740b0_7251_4d0e_9f0b_08dfcabc3aa5:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["\u00d6sterreichischer Werkbund", 2], ["\u00c9cole sup\u00e9rieure des arts d\u00e9coratifs de Strasbourg", 1], ["\u00c9cole normale sup\u00e9rieure de jeunes filles", 1], ["\u00c9cole nationale sup\u00e9rieure des arts visuels de La Cambre", 3], ["\u00c9cole nationale sup\u00e9rieure des arts d\u00e9coratifs", 5], ["\u00c9cole du Louvre", 4], ["\u00c9cole Libre des Sciences Politiques", 1], ["\u00c9cole Jeannine Manuel", 1], ["\u00c9cole Internationale Bilingue- Victor Hugo School", 1], ["\u00c9cole Duperr\u00e9", 4], ["\u00a5$", 1], ["\u00a1Hola!", 1], ["sadistics", 1], ["lyc\u00e9e Henri-Poincar\u00e9", 1], ["lyc\u00e9e Carnot", 1], ["liceo classico", 1], ["http://www.wikidata.org/.well-known/genid/4561ad7c9e49002c16f7acc8d0958bb0", 1], ["http://www.wikidata.org/.well-known/genid/16a32fbf717505bd050542efd591739e", 1], ["duPont Manual High School", 1], ["domaine de Boisbuchet", 1], ["carven", 1], ["Zurich University of the Arts", 1], ["Ziggy Marley and the Melody Makers", 1], ["Zicklin School of Business", 1], ["Zero", 1], ["Zemun Gymnasium", 1], ["Zara", 1], ["Zapeando", 1], ["Yves Saint Laurent", 1], ["Youth Performing Arts School", 1], ["Youngstown State University", 1], ["Young V&A", 1], ["Young Actors Space", 2], ["Yoshimoto New Star Creation", 1], ["York University", 2], ["Yeshivah of Flatbush", 1], ["Yellow Magic Orchestra", 1], ["Yale School of Drama", 2], ["Yale Law School", 1], ["Yaba College of Technology", 2], ["X Japan", 1], ["Wright State University", 1], ["Woodstock School", 1], ["Woodrow Wilson High School", 1], ["Woodbury University", 2], ["Woman's Home Companion", 1], ["Withington Girls' School", 2], ["Within Temptation", 1], ["Windlesham House School", 1], ["Wimbledon College of Art", 1], ["Wilson's School", 1], ["Wilmington Friends School", 1], ["Williams College", 1], ["Willem de Kooning Academy", 7], ["Wilkinson Sword", 1], ["Wilhelm-Gymnasium", 1], ["Wildwood School", 1], ["Wiener Werkst\u00e4tte", 6], ["Whitlockska samskolan", 1], ["White Zombie", 1], ["Wheels & Dollbaby", 1], ["Wheeler School", 1], ["Wethersfield High School", 1], ["Westminster School", 1], ["Westholme School", 1], ["Western University", 1], ["Westchester Enriched Sciences Magnets", 1], ["West University of Timi\u0219oara", 1], ["West Leyden High School", 1], ["Wesley Girls' High School", 1], ["Wendy's", 1], ["Wellington Polytechnic", 1], ["Wellington College", 1], ["Wei\u00dfensee Academy of Art Berlin", 2], ["Webster University", 1], ["Webber Douglas Academy of Dramatic Art", 1], ["WayV", 1], ["Waukesha County Technical College", 1], ["Watkins Mill High School", 1], ["Washingtonville High School", 1], ["Washington and Lee High School", 1], ["Washington University in St.\u00a0Louis", 3], ["Washington Adventist University", 1], ["Waseda University", 2], ["Waseda Jitsugyo", 1], ["Warwickshire College Group", 1], ["Warsaw University of Life Sciences", 1], ["Walthamstow College of Art", 3], ["Walsh School of Foreign Service", 1], ["Wako University", 1], ["WZRD", 1], ["Vytautas Magnus University", 1], ["Vogue Pattern Company", 1], ["Vogue Paris", 1], ["Vogue", 1], ["Vodka Collins", 1], ["Vkhutemas", 1], ["Vitebsk State Technological University", 2], ["Vital Voices", 1], ["Visakha Vidyalaya", 1], ["Virgil Abloh", 1], ["Vionnet", 1], ["Violet UK", 1], ["Vilnius University", 1], ["Vienna University of Economics and Business", 1], ["Victorian College of the Arts", 1], ["Versailles", 1], ["Vereniging van Edelsmeden en Sieraadontwerpers", 1], ["Verein der Berliner K\u00fcnstlerinnen", 1], ["Vera Wang", 1], ["Veo c\u00f3mo cantas", 1], ["Vassar College", 2], ["Varde Gymnasium", 1], ["Vantan", 1], ["Valentino", 2], ["Valentines High School", 1], ["Vakalo Art & Design College", 2], ["VOX", 1], ["VIA University College", 1], ["V2", 1], ["V L.O. im. Ks. J\u00f3zefa Poniatowskiego", 1], ["Utrecht School of the Arts", 1], ["Utah State University", 1], ["Universit\u00e0 Cattolica del Sacro Cuore", 1], ["University of the Witwate ...

# %%
### Effectif total et les plus représentées
len(organisations), organisations.sort_values(ascending=False).head(10)
# Out:
# (1589,
#  organisationLabel
#  Parsons School of Design                       73
#  Central Saint Martins                          61
#  Fashion Institute of Technology                53
#  Royal College of Art                           27
#  Royal Academy of Fine Arts                     25
#  London College of Fashion                      21
#  Bunka Fashion College                          19
#  Fashion Institute of Design & Merchandising    17
#  Saint Martin's School of Art                   17
#  Beaux-Arts de Paris                            13
#  dtype: int64)

# %% [markdown]
# ### Coder les périodes

# %%
bins=[1801,1921,1971,2021]

# %%
df['periode'] = pd.cut(df['birthYear'], bins=bins, right=False  )
df.periode = df.periode.apply( lambda x : str(x.left) + '_' + str(x.right))

# %%
df.head()
# Out:
#                                         item             itemLabel  birthYear  \
# 0   http://www.wikidata.org/entity/Q62128099     August Mannerheim       1805
# 1    http://www.wikidata.org/entity/Q5363058     Elizabeth Keckley       1818
# 2   http://www.wikidata.org/entity/Q64876982          John Redfern       1820
# 3  http://www.wikidata.org/entity/Q106151771  Madeleine Laferrière       1825
# 4    http://www.wikidata.org/entity/Q1255520  Alfred Isidore Römer       1832
#
#     r_property                             organisation  \
# 0     employer   http://www.wikidata.org/entity/Q194060
# 1     employer   http://www.wikidata.org/entity/Q215062
# 2     employer  http://www.wikidata.org/entity/Q7305826
# 3     employer  http://www.wikidata.org/entity/Q3278826
# 4  educated_at   http://www.wikidata.org/entity/Q414052
#
#               organisationLabel                      coordinates  YBegin  \
# 0               Bank of Finland                              NaN    1832
# 1             Mary Todd Lincoln                              NaN    1845
# 2                       Redfern                              NaN    1847
# 3             Maison Laferrière                              NaN    1852
# 4  Academy of Fine Arts, Munich  Point(11.580312391 48.15319592)    1849
#
#    YEnd    periode
# 0  1833  1801_1921
# 1  1846  1801_1921
# 2  1848  1801_1921
# 3  1853  1801_1921
# 4  1896  1801_1921

# %%
### Effectif par période
df.groupby(by='periode').size()
# Out:
# periode
# 1801_1921     272
# 1921_1971    1266
# 1971_2021    1129
# dtype: int64

# %%
### Dataframe to dictionary
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_dict.html
ldf = df[['itemLabel', 'r_property', 'organisationLabel',
       'YBegin', 'YEnd', 'birthYear', 'periode']].sort_values(by='itemLabel').to_dict('records')

# %%
ldf[:2]
# Out:
# [{'itemLabel': 'ASAP Bari',
#   'r_property': 'member_of',
#   'organisationLabel': 'ASAP Mob',
#   'YBegin': 2018,
#   'YEnd': 2055,
#   'birthYear': 1991,
#   'periode': '1971_2021'},
#  {'itemLabel': 'Aarni Soivio',
#   'r_property': 'educated_at',
#   'organisationLabel': 'Sibelius Upper Secondary School',
#   'YBegin': 2014,
#   'YEnd': 2061,
#   'birthYear': 1997,
#   'periode': '1971_2021'}]

# %% [markdown]
# ## Graphe à deux types de sommets
#
# Il s'agit d'un graphe de type 'bipartite', cf. la documentation de Networkx:
#
# https://networkx.org/documentation/stable/reference/algorithms/bipartite.html
#
# Nous n'utilisons toutefois pas ici les fonctions spécifiques de Neworkx.

# %%
l = []
for i in ldf:
    if i['periode'] == '1801_1921':
        l.append(tuple((i['itemLabel'],i['organisationLabel'],
                        {'relationship': i['r_property'], "birth_year": i['birthYear'], "periode": i['periode'] })))
l[:5]
# Out:
# [('Addie Masters',
#   'Affiliated Fashionists',
#   {'relationship': 'member_of', 'birth_year': 1901, 'periode': '1801_1921'}),
#  ('Adele Filene',
#   'Jantzen',
#   {'relationship': 'employer', 'birth_year': 1909, 'periode': '1801_1921'}),
#  ('Adele Filene',
#   'Vogue Pattern Company',
#   {'relationship': 'employer', 'birth_year': 1909, 'periode': '1801_1921'}),
#  ('Adolf Dassler',
#   'Adidas AG',
#   {'relationship': 'employer', 'birth_year': 1900, 'periode': '1801_1921'}),
#  ('Adrian',
#   'Parsons School of Design',
#   {'relationship': 'educated_at', 'birth_year': 1903, 'periode': '1801_1921'})]

# %%
# Graphe Personne-Organisation
POG=nx.Graph()

# %%
POG.add_edges_from(l)

# %%
### Principales caractéristiques de ce graphe

POG.is_multigraph(), POG.is_directed(), nx.is_connected(POG), POG.number_of_nodes(), POG.number_of_edges(), nx.density(POG)
# Out:
# (False, False, False, 369, 263, 0.0038735713444090964)

# %%
### Créer une liste des organisations
l_org = list(organisations.index); len(l_org); l_org[:6]
# Out:
# ['1st State Duma of the Russian Federation',
#  '20th Century Studios',
#  '2nd State Duma of the Russian Federation',
#  '3rd State Duma of the Russian Federation',
#  '43 Group',
#  'ABLF alumni network']

# %%
list(POG.nodes.data())[:4]
# Out:
# [('Addie Masters', {}),
#  ('Affiliated Fashionists', {}),
#  ('Adele Filene', {}),
#  ('Jantzen', {})]

# %%
### Ajouter au sommets un code si personne ou organisation
# On utiliser pour ce faire la liste des organisations
types = {}
for e in list(POG.nodes):
    if e in l_org:
        t = 'O'
    else:
        t = 'P'
    types[e] = {'type': t}
[(k,v )for k,v in types.items()][:3]
# Out:
# [('Addie Masters', {'type': 'P'}),
#  ('Affiliated Fashionists', {'type': 'O'}),
#  ('Adele Filene', {'type': 'P'})]

# %%
nx.set_node_attributes(POG, types)
list(POG.nodes.data())[:3]
# Out:
# [('Addie Masters', {'type': 'P'}),
#  ('Affiliated Fashionists', {'type': 'O'}),
#  ('Adele Filene', {'type': 'P'})]

# %% [markdown]
# ## Inspecter les centralités de degré
#
# " La centralité de degré repose sur le nombre de connexions directes que possède un nœud. Vous devez l’utiliser pour déterminer quels nœuds ont le plus d’influence directe. Par exemple, dans un réseau social, les utilisateurs qui ont le plus grand nombre de connexions bénéficient d’une centralité de degré plus élevée."
#
# https://doc.arcgis.com/fr/insights/latest/analyze/link-analysis.htm#:~:text=La%20centralit%C3%A9%20de%20degr%C3%A9%20repose,centralit%C3%A9%20de%20degr%C3%A9%20plus%20%C3%A9lev%C3%A9e.
#
# ---

# %%
### Ajouter la centralité de degré
# grâce à un dictionnaire construit selon le format souhaité
degree = dict([(d[0], {'degree': d[1]}) for d in nx.degree(POG)])

# %%
nx.set_node_attributes(POG, degree)

# %%
print(list(POG.nodes.data())[:4])
# Out:
# [('Addie Masters', {'type': 'P', 'degree': 1}), ('Affiliated Fashionists', {'type': 'O', 'degree': 1}), ('Adele Filene', {'type': 'P', 'degree': 2}), ('Jantzen', {'type': 'O', 'degree': 1})]

# %%
persons_degree = []
for n in list(POG.nodes.data()):
    if n[1]['type'] == 'P':
        persons_degree.append([n[0], n[1]['degree']])

# %%
sorted(persons_degree, key = lambda x : x[1], reverse=True)[:10]
# Out:
# [['Russell Patterson', 14],
#  ['Marie von Geldern-Egmond', 8],
#  ['Siri Derkert', 7],
#  ['Vera Mukhina', 7],
#  ['Edith Head', 4],
#  ['Heddi Hirsch', 4],
#  ['Hugo Boss', 4],
#  ['Jutta Sika', 4],
#  ['Osceola Macarthy Adams', 4],
#  ['Aili-Salli Ahde-Kjäldman', 3]]

# %%
org_degree = []
for n in list(POG.nodes.data()):
    if n[1]['type'] == 'O':
        org_degree.append([n[0], n[1]['degree']])

# %%
sorted(org_degree, key = lambda x : x[1], reverse=True)[:10]
# Out:
# [['Parsons School of Design', 8],
#  ['Art Students League of New York', 6],
#  ['University of Applied Arts Vienna', 6],
#  ['Wiener Werkstätte', 6],
#  ['Beaux-Arts de Paris', 5],
#  ['Pratt Institute', 3],
#  ['Académie de La Palette', 3],
#  ['Académie de la Grande Chaumière', 3],
#  ['Konstfack', 2],
#  ['Deutscher Werkbund', 2]]

# %%
edges = list(POG.edges.data())
edges[:5]
# Out:
# [('Addie Masters',
#   'Affiliated Fashionists',
#   {'relationship': 'member_of', 'birth_year': 1901, 'periode': '1801_1921'}),
#  ('Adele Filene',
#   'Jantzen',
#   {'relationship': 'employer', 'birth_year': 1909, 'periode': '1801_1921'}),
#  ('Adele Filene',
#   'Vogue Pattern Company',
#   {'relationship': 'employer', 'birth_year': 1909, 'periode': '1801_1921'}),
#  ('Adolf Dassler',
#   'Adidas AG',
#   {'relationship': 'employer', 'birth_year': 1900, 'periode': '1801_1921'}),
#  ('Adrian',
#   'Parsons School of Design',
#   {'relationship': 'educated_at', 'birth_year': 1903, 'periode': '1801_1921'})]

# %%
labels = {}
for node in POG.nodes():
    labels[node] = node

# %%
nx.set_node_attributes(POG, labels, 'label')

# %%
nodes = list(POG.nodes.data())
nodes[:5]
# Out:
# [('Addie Masters', {'type': 'P', 'degree': 1, 'label': 'Addie Masters'}),
#  ('Affiliated Fashionists',
#   {'type': 'O', 'degree': 1, 'label': 'Affiliated Fashionists'}),
#  ('Adele Filene', {'type': 'P', 'degree': 2, 'label': 'Adele Filene'}),
#  ('Jantzen', {'type': 'O', 'degree': 1, 'label': 'Jantzen'}),
#  ('Vogue Pattern Company',
#   {'type': 'O', 'degree': 1, 'label': 'Vogue Pattern Company'})]

# %% [markdown]
# ## Analyser les composantes du graphe
# Documentation: https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.components.connected_components.html

# %%
components = nx.connected_components(POG);
components_l = [len(c) for c in sorted(nx.connected_components(POG), key=len, reverse=True)]
len(components_l), components_l[:5]
# Out:
# (112, [44, 16, 15, 10, 10])

# %%
S = [POG.subgraph(c).copy() for c in nx.connected_components(POG)]

# %%
ln = sorted([[i,len(s.nodes)] for i,s in enumerate(S)], key = lambda row: row[1], reverse=True); ln[:8]
# Out:
# [[3, 44], [33, 16], [90, 15], [7, 10], [42, 10], [31, 7], [49, 5], [61, 5]]

# %%
li=[n[0] for n in ln]

# %%
S[21].nodes
# Out:
# NodeView(('Harrow School', 'Charles James'))

# %% [markdown]
# ## Représenter le graphe

# %%
u = S[14]

# %%
u = nx.Graph()
for i in li[:15]:
    u = nx.union(u, S[i])

# %%
### Principales caractéristiques de ce graphe

# MultiGraph: Undirected graphs with self loops and parallel edges
# https://networkx.org/documentation/stable/reference/classes/index.html

## ,nx.is_connected(G_1971_1975)
u.is_multigraph(), u.is_directed(), u.number_of_nodes(), u.number_of_edges(), nx.density(u)
# Out:
# (False, False, 141, 132, 0.013373860182370821)

# %%
### Visualiser l'ensemble des relations entre personnes et organisations (membres de / employé par ou étudié à)

# https://networkx.org/documentation/stable/reference/drawing.html
plt.figure(figsize = (30,30))

#g = POG
g = u

#pos = nx.kamada_kawai_layout(g)
pos = nx.spring_layout(g)

no = [x for x,y in g.nodes(data=True) if y['type']=='O']
np = [x for x,y in g.nodes(data=True) if y['type']=='P']

co = 'red'
cp = 'grey'
nx.draw_networkx_nodes(g, pos, nodelist=np, node_color=cp, alpha=0.6)
nx.draw_networkx_nodes(g, pos, nodelist=no, node_color=co, alpha=0.8)
nx.draw_networkx_edges(g, pos, alpha=0.6) # edgelist=ln, edge_color=c,
nx.draw_networkx_labels(g, pos, alpha=0.7, font_size=9)


plt.show()

# %%
###
# https://pyvis.readthedocs.io/en/latest/tutorial.html#using-pyvis-within-jupyter-notebook
nt = Network(notebook=True, cdn_resources='remote')
# populates the nodes and edges data structures
nt.from_nx(g)
nt.prep_notebook()
# Générer le fichier HTML contenant la visualisation
# nt.show('pictures.html' )
# display(HTML('pictures.html'))

# %% [markdown]
# ### Créer les paires de personnes

# %% [markdown]
# Personnes ayant étudié dans la même université ou travaillé chez le même employeur à la même époque:
#
# on teste si c'est la même université
#
# on teste s'il y a superposition des périodes

# %%
### Paires de personnes
pairs_p = []

for s1 in ldf:
    for s2 in ldf:
        if s1['itemLabel'] < s2['itemLabel'] \
            and s1['organisationLabel'] == s2['organisationLabel'] \
            and s2['YEnd'] > s1['YBegin'] \
            and s2['YBegin'] < s1['YEnd']:
            pairs_p.append([s1,s2])
        else:
            pass

# %%
len(pairs_p)
# Out:
# 7569

# %%
pairs_p[:2]
# Out:
# [[{'itemLabel': 'Abderrahmane Trabsini',
#    'r_property': 'educated_at',
#    'organisationLabel': 'Royal Academy of Art',
#    'YBegin': 2006,
#    'YEnd': 2053,
#    'birthYear': 1989,
#    'periode': '1971_2021'},
#   {'itemLabel': 'Hilde Sinke',
#    'r_property': 'educated_at',
#    'organisationLabel': 'Royal Academy of Art',
#    'YBegin': 1992,
#    'YEnd': 2039,
#    'birthYear': 1975,
#    'periode': '1971_2021'}],
#  [{'itemLabel': 'Abderrahmane Trabsini',
#    'r_property': 'educated_at',
#    'organisationLabel': 'Royal Academy of Art',
#    'YBegin': 2006,
#    'YEnd': 2053,
#    'birthYear': 1989,
#    'periode': '1971_2021'},
#   {'itemLabel': 'Lotte van Laatum',
#    'r_property': 'educated_at',
#    'organisationLabel': 'Royal Academy of Art',
#    'YBegin': 1996,
#    'YEnd': 2043,
#    'birthYear': 1979,
#    'periode': '1971_2021'}]]

# %% [markdown]
# ### Créer les paires d'organisations
# Une personne fait le lien entre deux organisations

# %%
## Paires d'organisations
pairs_o = []

for s1 in ldf:
    for s2 in ldf:
        if s1['organisationLabel'] < s2['organisationLabel'] \
            and s1['itemLabel'] == s2['itemLabel']:
                pairs_o.append([s1,s2])
        else:
            pass

# %% [markdown]
# ## Pairs d'organisations
# pairs_o = []
#
# for s1 in ldf:
#     for s2 in ldf:
#         if s1['target'] < s2['target'] \
#             and s1['subject_uri'] == s2['subject_uri']:
#                 pairs_o.append([s1,s2])
#         else:
#             pass

# %%
len(pairs_o)
# Out:
# 2430

# %%
### Apparaissent des parcours de vie
pairs_o[:2]
# Out:
# [[{'itemLabel': 'Aarni Soivio',
#    'r_property': 'member_of',
#    'organisationLabel': 'Kuumaa',
#    'YBegin': 2024,
#    'YEnd': 2061,
#    'birthYear': 1997,
#    'periode': '1971_2021'},
#   {'itemLabel': 'Aarni Soivio',
#    'r_property': 'educated_at',
#    'organisationLabel': 'Sibelius Upper Secondary School',
#    'YBegin': 2014,
#    'YEnd': 2061,
#    'birthYear': 1997,
#    'periode': '1971_2021'}],
#  [{'itemLabel': 'Abiodun Folashade Tokunbo',
#    'r_property': 'educated_at',
#    'organisationLabel': 'Lagos State University',
#    'YBegin': 1997,
#    'YEnd': 2044,
#    'birthYear': 1980,
#    'periode': '1971_2021'},
#   {'itemLabel': 'Abiodun Folashade Tokunbo',
#    'r_property': 'educated_at',
#    'organisationLabel': 'The Polytechnic, Ibadan',
#    'YBegin': 1997,
#    'YEnd': 2044,
#    'birthYear': 1980,
#    'periode': '1971_2021'}]]

# %% [markdown]
# ## Réseaux de personnes ayant étudié ou travaillé dans la même institution à la même époque (filtres, sous-populations)

# %%
XIX_XX_pairs = [p for p in pairs_p if ((p[0]['periode']=='1801_1921') & (p[1]['periode']=='1801_1921'))]

# %%
len(XIX_XX_pairs), XIX_XX_pairs[:3]
# Out:
# (98,
#  [[{'itemLabel': 'Adrian',
#     'r_property': 'educated_at',
#     'organisationLabel': 'Parsons School of Design',
#     'YBegin': 1920,
#     'YEnd': 1967,
#     'birthYear': 1903,
#     'periode': '1801_1921'},
#    {'itemLabel': 'Claire McCardell',
#     'r_property': 'educated_at',
#     'organisationLabel': 'Parsons School of Design',
#     'YBegin': 1922,
#     'YEnd': 1969,
#     'birthYear': 1905,
#     'periode': '1801_1921'}],
#   [{'itemLabel': 'Adrian',
#     'r_property': 'educated_at',
#     'organisationLabel': 'Parsons School of Design',
#     'YBegin': 1920,
#     'YEnd': 1967,
#     'birthYear': 1903,
#     'periode': '1801_1921'},
#    {'itemLabel': 'Ethel Myers',
#     'r_property': 'educated_at',
#     'organisationLabel': 'Parsons School of Design',
#     'YBegin': 1898,
#     'YEnd': 1945,
#     'birthYear': 1881,
#     'periode': '1801_1921'}],
#   [{'itemLabel': 'Adrian',
#     'r_property': 'educated_at',
#     'organisationLabel': 'Parsons School of Design',
#     'YBegin': 1920,
#     'YEnd': 1967,
#     'birthYear': 1903,
#     'periode': '1801_1921'},
#    {'itemLabel': 'Irene Sharaff',
#     'r_property': 'educated_at',
#     'organisationLabel': 'Parsons School of Design',
#     'YBegin': 1927,
#     'YEnd': 1974,
#     'birthYear': 1910,
#     'periode': '1801_1921'}]])

# %%
almaMater_pairs = [p for p in pairs_p if ((p[0]['r_property'] == 'educated_at') & (p[1]['r_property'] == 'educated_at'))]

# %%
len(almaMater_pairs), almaMater_pairs[:2]
# Out:
# (7201,
#  [[{'itemLabel': 'Abderrahmane Trabsini',
#     'r_property': 'educated_at',
#     'organisationLabel': 'Royal Academy of Art',
#     'YBegin': 2006,
#     'YEnd': 2053,
#     'birthYear': 1989,
#     'periode': '1971_2021'},
#    {'itemLabel': 'Hilde Sinke',
#     'r_property': 'educated_at',
#     'organisationLabel': 'Royal Academy of Art',
#     'YBegin': 1992,
#     'YEnd': 2039,
#     'birthYear': 1975,
#     'periode': '1971_2021'}],
#   [{'itemLabel': 'Abderrahmane Trabsini',
#     'r_property': 'educated_at',
#     'organisationLabel': 'Royal Academy of Art',
#     'YBegin': 2006,
#     'YEnd': 2053,
#     'birthYear': 1989,
#     'periode': '1971_2021'},
#    {'itemLabel': 'Lotte van Laatum',
#     'r_property': 'educated_at',
#     'organisationLabel': 'Royal Academy of Art',
#     'YBegin': 1996,
#     'YEnd': 2043,
#     'birthYear': 1979,
#     'periode': '1971_2021'}]])

# %% [markdown]
# ## Exploration des graphes de personnes

# %% [markdown]
# ### Période 1801-1921

# %%
### Préparer pour créer le graphe
l = []
for i in XIX_XX_pairs: #personnes ayan étudié aux mêmes insitutions  pour la période 1801-1921
    l.append(tuple((i[0]['itemLabel'],i[1]['itemLabel'], {'relationship': f"{i[0]['r_property']}_{i[1]['r_property']}",
                                                              'organisation': i[0]['organisationLabel'] })))
l[:7]
# Out:
# [('Adrian',
#   'Claire McCardell',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrian',
#   'Ethel Myers',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrian',
#   'Irene Sharaff',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrian',
#   'Jo Copeland',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrian',
#   'Lila Bath',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrian',
#   'Robert Kalloch',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrian',
#   'Van Day Truex',
#   {'relationship': 'educated_at_employer',
#    'organisation': 'Parsons School of Design'})]

# %%
EMP=nx.Graph()

# %%
EMP.add_edges_from(l)

# %%
### Principales caractéristiques de ce graphe

EMP.is_multigraph(), EMP.is_directed(), nx.is_connected(EMP), EMP.number_of_nodes(), EMP.number_of_edges(), nx.density(EMP)
# Out:
# (False, False, False, 49, 86, 0.07312925170068027)

# %%
nodes = list(EMP.nodes.data())
nodes[:5]
# Out:
# [('Adrian', {}),
#  ('Claire McCardell', {}),
#  ('Ethel Myers', {}),
#  ('Irene Sharaff', {}),
#  ('Jo Copeland', {})]

# %%
edges = list(EMP.edges.data())
edges[:5]
# Out:
# [('Adrian',
#   'Claire McCardell',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrian',
#   'Ethel Myers',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrian',
#   'Irene Sharaff',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrian',
#   'Jo Copeland',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrian',
#   'Lila Bath',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'})]

# %%
labels = {}
for node in EMP.nodes():
    labels[node] = node

# %%
###
# https://pyvis.readthedocs.io/en/latest/tutorial.html#using-pyvis-within-jupyter-notebook
# Créer un objet Network de PyVis avec l'option cdn_resources='remote'
nt = Network(notebook=True, cdn_resources='remote')
# populates the nodes and edges data structures
nt.from_nx(EMP)
nt.prep_notebook()
# Générer le fichier HTML contenant la visualisation
# nt.show('graph.html')
# display(HTML('graph.html'))

# %% [markdown]
# ### Analyser les composantes du graphe
# Documentation: https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.components.connected_components.html

# %%
nx.is_connected(EMP)
# Out:
# False

# %%
# filtre qui va chercher les composantes qui sont connectées --> liste des composantes qui se trouve ds la variable component
components = nx.connected_components(EMP);
components_l = [len(c) for c in sorted(nx.connected_components(EMP), key=len, reverse=True)]
len(components_l), components_l[:5]
## résultat: 12 composantes
# Out:
# (12, [18, 8, 5, 2, 2])

# %%
S = [EMP.subgraph(c).copy() for c in nx.connected_components(EMP)]
# création d'une liste des sous-graph

# %%
ln = sorted([[i,len(s.nodes)] for i,s in enumerate(S)], key = lambda row: row[1], reverse=True); ln[:8]
#parcourir ces sous-graph et les "cuisiner"
# Out:
# [[0, 18], [5, 8], [6, 5], [1, 2], [2, 2], [3, 2], [4, 2], [7, 2]]

# %%
li=[n[0] for n in ln]
## résultats dans l'ordre des effectifs

# %% [markdown]
# ### Représenter le graphe

# %%
u = nx.Graph()
for i in li[0:2]:
    u = nx.union(u, S[i])

# %%
### Principales caractéristiques de ce graphe

# MultiGraph: Undirected graphs with self loops and parallel edges
# https://networkx.org/documentation/stable/reference/classes/index.html

## ,nx.is_connected(G_1971_1975)
u.is_multigraph(), u.is_directed(), u.number_of_nodes(), u.number_of_edges(), nx.density(u)
# Out:
# (False, False, 26, 67, 0.20615384615384616)

# %%
u = S[5]

# %%
# https://networkx.org/documentation/stable/reference/drawing.html


plt.figure(figsize = (15,15))

#g = POG
g = u

#pos = nx.kamada_kawai_layout(g)
### https://networkx.org/documentation/stable/reference/generated/networkx.drawing.layout.spring_layout.html

pos = nx.spring_layout(u, k=1)

labels = {e: u.get_edge_data(e[0], e[1])["organisation"] for e in u.edges()}

cp = 'grey'
nx.draw_networkx_nodes(g, pos, node_color=cp, alpha=0.8)
nx.draw_networkx_edges(g, pos, alpha=0.6) # edgelist=ln, edge_color=c,
nx.draw_networkx_labels(g, pos, alpha=0.7, font_size=11)
nx.draw_networkx_edge_labels(g, pos=pos, edge_labels=labels)

# Vérification et création du répertoire 'images' si nécessaire
os.makedirs('images', exist_ok=True)

# Enregistrement de l'image
f_address = "images/XIX_XX_pairs_1.png"
plt.savefig(f_address)

# Affichage de l'image
plt.show()

# %% [markdown]
# ### Période1921_1971

# %%
early20_pairs = [p for p in pairs_p if ((p[0]['periode']=='1921_1971') & (p[1]['periode']=='1921_1971'))]

# %%
### Préparer pour créer le graphe
l = []
for i in early20_pairs: #lien général personne à personne
    l.append(tuple((i[0]['itemLabel'],i[1]['itemLabel'], {'relationship': f"{i[0]['r_property']}_{i[1]['r_property']}",
                                                              'organisation': i[0]['organisationLabel'] })))
l[:5]
# Out:
# [('Adrienne Steckling-Coen',
#   'Alfred Sung',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrienne Steckling-Coen',
#   'Anna Sui',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrienne Steckling-Coen',
#   'Bill Blass',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrienne Steckling-Coen',
#   'Carine Roitfeld',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrienne Steckling-Coen',
#   'Christian Francis Roth',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'})]

# %%
EMP=nx.Graph()

# %%
EMP.add_edges_from(l)

# %%
nodes = list(EMP.nodes.data())
nodes[:5]
# Out:
# [('Adrienne Steckling-Coen', {}),
#  ('Alfred Sung', {}),
#  ('Anna Sui', {}),
#  ('Bill Blass', {}),
#  ('Carine Roitfeld', {})]

# %%
edges = list(EMP.edges.data())
edges[:5]
# Out:
# [('Adrienne Steckling-Coen',
#   'Alfred Sung',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrienne Steckling-Coen',
#   'Anna Sui',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrienne Steckling-Coen',
#   'Bill Blass',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrienne Steckling-Coen',
#   'Carine Roitfeld',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'}),
#  ('Adrienne Steckling-Coen',
#   'Christian Francis Roth',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Parsons School of Design'})]

# %%
labels = {}
for node in EMP.nodes():
    labels[node] = node

# %%
###
# https://pyvis.readthedocs.io/en/latest/tutorial.html#using-pyvis-within-jupyter-notebook
# Créer un objet Network de PyVis avec l'option cdn_resources='remote'
nt = Network(notebook=True, cdn_resources='remote')
# populates the nodes and edges data structures
nt.from_nx(EMP)
nt.prep_notebook()
# Générer le fichier HTML contenant la visualisation
# nt.show('graph1.html')
# display(HTML('graph1.html'))

# %% [markdown]
# ### Analyser les composantes du graphe
# Documentation: https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.components.connected_components.html

# %%
components = nx.connected_components(EMP);
components_l = [len(c) for c in sorted(nx.connected_components(EMP), key=len, reverse=True)]
len(components_l), components_l[:5]
# Out:
# (44, [220, 16, 16, 14, 11])

# %%
S = [EMP.subgraph(c).copy() for c in nx.connected_components(EMP)]

# %%
ln = sorted([[i,len(s.nodes)] for i,s in enumerate(S)], key = lambda row: row[1], reverse=True); ln[:8]
# Out:
# [[0, 220], [5, 16], [42, 16], [1, 14], [9, 11], [29, 8], [3, 7], [11, 7]]

# %%
li=[n[0] for n in ln]

# %% [markdown]
# ### Représenter le graphe

# %%
u = nx.Graph()
for i in li[1:3]:
    u = nx.union(u, S[i])

# %%
u = S[5]

# %%
# https://networkx.org/documentation/stable/reference/drawing.html
plt.figure(figsize = (15,15))

#g = POG
g = u

#pos = nx.kamada_kawai_layout(g)
### https://networkx.org/documentation/stable/reference/generated/networkx.drawing.layout.spring_layout.html

pos = nx.spring_layout(u, k=1)

labels = {e: u.get_edge_data(e[0], e[1])["organisation"] for e in u.edges()}

cp = 'grey'
nx.draw_networkx_nodes(g, pos, node_color=cp, alpha=0.8)
nx.draw_networkx_edges(g, pos, alpha=0.6) # edgelist=ln, edge_color=c,
nx.draw_networkx_labels(g, pos, alpha=0.7, font_size=11)
nx.draw_networkx_edge_labels(g, pos=pos, edge_labels=labels)



plt.show()

# %% [markdown]
# ### Période 1971_2021

# %%
end20_pairs = [p for p in pairs_p if ((p[0]['periode']=='1971_2021') & (p[1]['periode']=='1971_2021'))]

# %%
### Préparer pour créer le graphe
l = []
for i in end20_pairs: #personnes ayan été en lien pour la période 1971_2021
    l.append(tuple((i[0]['itemLabel'],i[1]['itemLabel'], {'relationship': f"{i[0]['r_property']}_{i[1]['r_property']}",
                                                              'organisation': i[0]['organisationLabel'] })))
l[:4]
# Out:
# [('Abderrahmane Trabsini',
#   'Hilde Sinke',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Royal Academy of Art'}),
#  ('Abderrahmane Trabsini',
#   'Lotte van Laatum',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Royal Academy of Art'}),
#  ('Abderrahmane Trabsini',
#   'Sara Vrugt',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Royal Academy of Art'}),
#  ('Abiodun Folashade Tokunbo',
#   'Ruggedman',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Lagos State University'})]

# %%
EMP=nx.Graph()

# %%
EMP.add_edges_from(l)

# %%
nodes = list(EMP.nodes.data())
nodes[:5]
# Out:
# [('Abderrahmane Trabsini', {}),
#  ('Hilde Sinke', {}),
#  ('Lotte van Laatum', {}),
#  ('Sara Vrugt', {}),
#  ('Abiodun Folashade Tokunbo', {})]

# %%
edges = list(EMP.edges.data())
edges[:3]
# Out:
# [('Abderrahmane Trabsini',
#   'Hilde Sinke',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Royal Academy of Art'}),
#  ('Abderrahmane Trabsini',
#   'Lotte van Laatum',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Royal Academy of Art'}),
#  ('Abderrahmane Trabsini',
#   'Sara Vrugt',
#   {'relationship': 'educated_at_educated_at',
#    'organisation': 'Royal Academy of Art'})]

# %%
labels = {}
for node in EMP.nodes():
    labels[node] = node

# %%
###
# https://pyvis.readthedocs.io/en/latest/tutorial.html#using-pyvis-within-jupyter-notebook
# Créer un objet Network de PyVis avec l'option cdn_resources='remote'
nt = Network(notebook=True, cdn_resources='remote')
# populates the nodes and edges data structures
nt.from_nx(EMP)
nt.prep_notebook()
# Générer le fichier HTML contenant la visualisation
# nt.show('graph2.html')
# display(HTML('graph2.html'))

# %% [markdown]
# ### Analyser les composantes du graphe

# %%
components = nx.connected_components(EMP);
components_l = [len(c) for c in sorted(nx.connected_components(EMP), key=len, reverse=True)]
len(components_l), components_l[:5]
# Out:
# (56, [193, 21, 9, 6, 5])

# %%
S = [EMP.subgraph(c).copy() for c in nx.connected_components(EMP)]

# %%
ln = sorted([[i,len(s.nodes)] for i,s in enumerate(S)], key = lambda row: row[1], reverse=True); ln[:8]
# Out:
# [[4, 193], [8, 21], [23, 9], [22, 6], [3, 5], [6, 5], [31, 5], [42, 5]]

# %%
li=[n[0] for n in ln]

# %% [markdown]
# ### Représenter le graphe

# %%
u = nx.Graph()
for i in li[1:3]:
    u = nx.union(u, S[i])

# %%
u = S[5]

# %%
# https://networkx.org/documentation/stable/reference/drawing.html
plt.figure(figsize = (15,15))

#g = POG
g = u

#pos = nx.kamada_kawai_layout(g)
### https://networkx.org/documentation/stable/reference/generated/networkx.drawing.layout.spring_layout.html

pos = nx.spring_layout(u, k=1)

labels = {e: u.get_edge_data(e[0], e[1])["organisation"] for e in u.edges()}

cp = 'grey'
nx.draw_networkx_nodes(g, pos, node_color=cp, alpha=0.8)
nx.draw_networkx_edges(g, pos, alpha=0.6) # edgelist=ln, edge_color=c,
nx.draw_networkx_labels(g, pos, alpha=0.7, font_size=11)
nx.draw_networkx_edge_labels(g, pos=pos, edge_labels=labels)


plt.show()

# %% [markdown]
# ## Explorer le graphe des organisations (relation Alma Mater)

# %%
### Apparaissent des parcours de vie
pairs_o[:2]
# Out:
# [[{'itemLabel': 'Aarni Soivio',
#    'r_property': 'member_of',
#    'organisationLabel': 'Kuumaa',
#    'YBegin': 2024,
#    'YEnd': 2061,
#    'birthYear': 1997,
#    'periode': '1971_2021'},
#   {'itemLabel': 'Aarni Soivio',
#    'r_property': 'educated_at',
#    'organisationLabel': 'Sibelius Upper Secondary School',
#    'YBegin': 2014,
#    'YEnd': 2061,
#    'birthYear': 1997,
#    'periode': '1971_2021'}],
#  [{'itemLabel': 'Abiodun Folashade Tokunbo',
#    'r_property': 'educated_at',
#    'organisationLabel': 'Lagos State University',
#    'YBegin': 1997,
#    'YEnd': 2044,
#    'birthYear': 1980,
#    'periode': '1971_2021'},
#   {'itemLabel': 'Abiodun Folashade Tokunbo',
#    'r_property': 'educated_at',
#    'organisationLabel': 'The Polytechnic, Ibadan',
#    'YBegin': 1997,
#    'YEnd': 2044,
#    'birthYear': 1980,
#    'periode': '1971_2021'}]]

# %%
l = []
for i in pairs_o:
    if i[0]['r_property'] == 'educated_at' or  i[1]['r_property'] == 'educated_at':
        l.append(tuple((i[0]['organisationLabel'],i[1]['organisationLabel'], {'relationship': f"{i[0]['r_property']}_{i[1]['r_property']}",
                                                              'personne': i[0]['itemLabel'] })))
len(l), l[:3]
# Out:
# (1761,
#  [('Kuumaa',
#    'Sibelius Upper Secondary School',
#    {'relationship': 'member_of_educated_at', 'personne': 'Aarni Soivio'}),
#   ('Lagos State University',
#    'The Polytechnic, Ibadan',
#    {'relationship': 'educated_at_educated_at',
#     'personne': 'Abiodun Folashade Tokunbo'}),
#   ('Lagos State University',
#    'The Polytechnic, Ibadan',
#    {'relationship': 'educated_at_educated_at',
#     'personne': 'Abiodun Folashade Tokunbo'})])

# %%
### Graphe des organisation, liens AlmaMater

amO=nx.Graph()

# %%
amO.add_edges_from(l)

# %%
### Principales caractéristiques de ce graphe

# MultiGraph: Undirected graphs with self loops and parallel edges
# https://networkx.org/documentation/stable/reference/classes/index.html

##amO.is_directed() ,nx.is_connected(G_1971_1975)
amO.is_multigraph(),nx.is_connected(amO) , amO.number_of_nodes(), amO.number_of_edges(), nx.density(amO)
# Out:
# (False, False, 1138, 1525, 0.002357203691767408)

# %%
nodes = list(amO.nodes.data())
nodes[:5]
# Out:
# [('Kuumaa', {}),
#  ('Sibelius Upper Secondary School', {}),
#  ('Lagos State University', {}),
#  ('The Polytechnic, Ibadan', {}),
#  ('Cornell University', {})]

# %%
edges = list(amO.edges.data())
edges[:5]
# Out:
# [('Kuumaa',
#   'Sibelius Upper Secondary School',
#   {'relationship': 'member_of_educated_at', 'personne': 'Aarni Soivio'}),
#  ('Lagos State University',
#   'The Polytechnic, Ibadan',
#   {'relationship': 'educated_at_educated_at',
#    'personne': 'Abiodun Folashade Tokunbo'}),
#  ('Cornell University',
#   'Nichols School',
#   {'relationship': 'educated_at_educated_at', 'personne': 'Adam Lippes'}),
#  ('Cornell University',
#   'Gallatin School of Individualized Study',
#   {'relationship': 'educated_at_educated_at', 'personne': 'Lynn Ban'}),
#  ('Cornell University',
#   'Agnes Irwin School',
#   {'relationship': 'educated_at_educated_at', 'personne': 'Vanessa Noel'})]

# %% [markdown]
# ### Analyser les composantes du graphe
#
# Documentation: https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.components.connected_components.html

# %%
components = nx.connected_components(amO);
components_l = [len(c) for c in sorted(nx.connected_components(amO), key=len, reverse=True)]
len(components_l), components_l[:5]
# Out:
# (187, [567, 23, 20, 18, 11])

# %%
largest_cc = max(nx.connected_components(amO), key=len); type(largest_cc)
# Out:
# set

# %%
S = amO.subgraph(largest_cc).copy()

# %%
### Principales caractéristiques de ce graphe

# MultiGraph: Undirected graphs with self loops and parallel edges
# https://networkx.org/documentation/stable/reference/classes/index.html

##amO.is_directed() ,nx.is_connected(G_1971_1975)
S.is_multigraph(),nx.is_connected(S) , S.number_of_nodes(), S.number_of_edges(), nx.density(S)
# Out:
# (False, True, 567, 1030, 0.0064190052411489396)

# %% [markdown]
# ### Centralité de degré

# %%
# On construit ici le dictionnaire selon le format souhaité
degree = dict([(d[0], {'degree': d[1]}) for d in nx.degree(S)])

# %%
nx.set_node_attributes(amO, degree)
print(list(amO.nodes.data())[:3])
# Out:
# [('Kuumaa', {}), ('Sibelius Upper Secondary School', {}), ('Lagos State University', {})]

# %% [markdown]
# ### Centralité de proximité

# %%
closeness = nx.closeness_centrality(amO)

# %%
nx.set_node_attributes(amO, closeness, 'closeness')
# print(G.nodes.data())

# %% [markdown]
# ### Centralité d'intermédiarité

# %%
betweenness = nx.betweenness_centrality(amO)

# %%
nx.set_node_attributes(amO, betweenness, 'betweenness')

# %%
### Exporter les attributs vers un DataFrame afin de les explorer
export = pd.DataFrame(amO.nodes.data(), columns = ['id', 'attributes'])
#export = export.set_index('id')
export.head()
# Out:
#                                 id  \
# 0                           Kuumaa
# 1  Sibelius Upper Secondary School
# 2           Lagos State University
# 3          The Polytechnic, Ibadan
# 4               Cornell University
#
#                                           attributes
# 0  {'closeness': 0.0008795074758135445, 'betweenn...
# 1  {'closeness': 0.0008795074758135445, 'betweenn...
# 2  {'closeness': 0.0008795074758135445, 'betweenn...
# 3  {'closeness': 0.0008795074758135445, 'betweenn...
# 4  {'degree': 3, 'closeness': 0.09115350919499315...

# %%
### Décomposer le champs attributs en colonnes
# https://stackoverflow.com/questions/38231591/split-explode-a-column-of-dictionaries-into-separate-columns-with-pandas

attributes = pd.json_normalize(export.attributes)

## Retour à affichage des décimales par défaut:
pd.options.display.float_format = '{: }'.format  # pour 4 chiffres : 4f


round(attributes, 4)
# Out:
#       closeness  betweenness  degree
# 0        0.0009          0.0     NaN
# 1        0.0009          0.0     NaN
# 2        0.0009          0.0     NaN
# 3        0.0009          0.0     NaN
# 4        0.0912       0.0017     3.0
# ...         ...          ...     ...
# 1133     0.0009          0.0     NaN
# 1134     0.0009          0.0     NaN
# 1135     0.0012          0.0     NaN
# 1136     0.0009          0.0     NaN
# 1137     0.0009          0.0     NaN
#
# [1138 rows x 3 columns]

# %%
### appliquer au DataFrame et supprimer la colonne attributes
# en même temps mettre le nom en index
# export = export.join(pd.json_normalize(export.attributes)).set_index('id')
export = export.join(attributes)
export = export.drop(columns=['attributes'],axis=1)
export.head()
# Out:
#                                 id              closeness  \
# 0                           Kuumaa  0.0008795074758135445
# 1  Sibelius Upper Secondary School  0.0008795074758135445
# 2           Lagos State University  0.0008795074758135445
# 3          The Polytechnic, Ibadan  0.0008795074758135445
# 4               Cornell University    0.09115350919499315
#
#              betweenness  degree
# 0                    0.0     NaN
# 1                    0.0     NaN
# 2                    0.0     NaN
# 3                    0.0     NaN
# 4  0.0017481759510448798     3.0

# %%
round(export.sort_values(by=['degree'], ascending=False).head(20),3)
# Out:
#                                               id  closeness  betweenness  \
# 47                      Parsons School of Design      0.158        0.081
# 42                         Central Saint Martins      0.157        0.085
# 70               Fashion Institute of Technology      0.173        0.123
# 56                          Royal College of Art      0.131        0.022
# 26   Fashion Institute of Design & Merchandising      0.126        0.014
# 135                 Saint Martin's School of Art      0.142         0.02
# 156              Art Students League of New York      0.141        0.017
# 232                          Beaux-Arts de Paris      0.095        0.007
# 108                          New York University      0.139        0.009
# 23                         Bunka Fashion College      0.083        0.011
# 389                          University of Paris      0.137        0.024
# 119                    London College of Fashion      0.143        0.018
# 53                 Rhode Island School of Design       0.13        0.018
# 585                         Santa Monica College      0.096        0.002
# 34                            The Buckley School      0.112        0.005
# 284               Otis College of Art and Design      0.115        0.017
# 407              Académie de la Grande Chaumière      0.121        0.011
# 106                   University of Pennsylvania      0.112        0.006
# 993                           Académie Colarossi      0.098          0.0
# 317                         Paris College of Art      0.126        0.003
#
#      degree
# 47     65.0
# 42     62.0
# 70     46.0
# 56     31.0
# 26     18.0
# 135    17.0
# 156    16.0
# 232    16.0
# 108    16.0
# 23     14.0
# 389    14.0
# 119    14.0
# 53     14.0
# 585    14.0
# 34     13.0
# 284    13.0
# 407    12.0
# 106    12.0
# 993    11.0
# 317    11.0

# %%
export['degree'].describe()
## permet de filter la population > la majorité des individu à un degré 4 ou moins ( 1,2,3)
# Out:
# count                567.0
# mean       3.6331569664903
# std      5.046724552472974
# min                    1.0
# 25%                    1.0
# 50%                    2.0
# 75%                    4.0
# max                   65.0
# Name: degree, dtype: float64

# %%
kamo = nx.k_core(amO, k=5)

# %%
### Principales caractéristiques de ce graphe

# MultiGraph: Undirected graphs with self loops and parallel edges
# https://networkx.org/documentation/stable/reference/classes/index.html

##amO.is_directed() ,nx.is_connected(G_1971_1975)
kamo.is_multigraph(),nx.is_connected(kamo) , kamo.number_of_nodes(), kamo.number_of_edges(), nx.density(kamo)
# Out:
# (False, False, 48, 151, 0.13386524822695037)

# %%
components = nx.connected_components(kamo);
components_l = [len(c) for c in sorted(nx.connected_components(kamo), key=len, reverse=True)]
len(components_l), components_l[:5]
# Out:
# (4, [21, 15, 6, 6])

# %%
largest_cc = max(nx.connected_components(kamo), key=len)

# %%
new_cc = sorted(nx.connected_components(kamo), key=len, reverse=True)[1]

# %%
S = kamo.subgraph(new_cc).copy()

# %% [markdown]
# ### Représenter le graphe

# %%
### Principales caractéristiques de ce graphe

# MultiGraph: Undirected graphs with self loops and parallel edges
# https://networkx.org/documentation/stable/reference/classes/index.html
u = S
## ,nx.is_connected(G_1971_1975) u.is_directed(),
u.is_multigraph(), nx.is_connected(u), u.number_of_nodes(), u.number_of_edges(), nx.density(u)
# Out:
# (False, True, 15, 57, 0.5428571428571428)

# %%
list(u.nodes.data())[1:3]
# Out:
# [('Sonic Youth',
#   {'degree': 7, 'closeness': 0.09477144195147119, 'betweenness': 0.0}),
#  ('Otis College of Art and Design',
#   {'degree': 13,
#    'closeness': 0.1154735643121819,
#    'betweenness': 0.016599249859381264})]

# %%
labels = {}
for i in list(u.nodes.data()):
    if i[1]['degree'] >1:
        labels[i[0]]=i[0]
list(labels.items())[:3]
# Out:
# [('University High School', 'University High School'),
#  ('Sonic Youth', 'Sonic Youth'),
#  ('Otis College of Art and Design', 'Otis College of Art and Design')]

# %%
# https://networkx.org/documentation/stable/reference/drawing.html
plt.figure(figsize = (15,15))

#g = POG
g = u

#pos = nx.kamada_kawai_layout(g)
### https://networkx.org/documentation/stable/reference/generated/networkx.drawing.layout.spring_layout.html
pos = nx.spring_layout(g, k=1)

labels = {}
for i in list(u.nodes.data()):
    if i[1]['degree'] > 1:# degré filtre les résultats
        labels[i[0]]=i[0]

node_color = [i[1]['degree'] for i in list(u.nodes.data())]

### Adapter la taille des attribut à l'affichage
node_sizes = [i[1]['betweenness']**2 * 10000000 + 10 for i in list(u.nodes.data())] # visualisation de la taille


cp = 'grey'
nx.draw_networkx_nodes(g, pos, node_size=node_sizes, node_color=node_color,
                      cmap='copper', alpha=0.6)
nx.draw_networkx_edges(g, pos, alpha=0.05) # edgelist=ln, edge_color=c,
nx.draw_networkx_labels(g, pos, labels=labels,  alpha=0.7, font_size=11)
#nx.draw_networkx_edge_labels(g, pos=pos, edge_labels=labels)

f = 'pictures/universites.svg'# io.BytesIO()

plt.show()
